# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
laptop_data = pd.read_csv('datasets/laptops.csv', encoding='ISO-8859-1', index_col=1)
laptop_data.head()
# Out:
#          Unnamed: 0      Product   TypeName  Inches  \
# Company
# Apple             1  MacBook Pro  Ultrabook    13.3
# Apple             2  Macbook Air  Ultrabook    13.3
# HP                3       250 G6   Notebook    15.6
# Apple             4  MacBook Pro  Ultrabook    15.4
# Apple             5  MacBook Pro  Ultrabook    13.3
#
#                            ScreenResolution                         Cpu   Ram  \
# Company
# Apple    IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# Apple                              1440x900        Intel Core i5 1.8GHz   8GB
# HP                        Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# Apple    IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# Apple    IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                       Memory                           Gpu  OpSys  Weight  \
# Company
# Apple              128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# Apple    128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# HP                 256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# Apple              512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# Apple              256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#          Price_euros
# Company
# Apple        1339.69
# Apple         898.94
# HP            575.00
# Apple        2537.45
# Apple        1803.60

# %%
laptop_data.sample(10)
# Out:
#          Unnamed: 0                              Product            TypeName  \
# Company
# HP              386                       Omen 17-w212nv              Gaming
# HP             1182                               250 G4            Notebook
# Lenovo          645                   IdeaPad 100S-14IBR            Notebook
# HP             1053                          ProBook 440            Notebook
# Acer            143                             Aspire 5            Notebook
# Dell           1108                        Inspiron 5370           Ultrabook
# Asus            526   FX753VE-GC155T (i7-7700HQ/16GB/1TB              Gaming
# Lenovo         1214  V110-15ISK (i3-6006U/4GB/1TB/Radeon            Notebook
# Asus            354                        VivoBook Flip  2 in 1 Convertible
# HP             1017                          Probook 440            Notebook
#
#          Inches             ScreenResolution  \
# Company
# HP         17.3  IPS Panel Full HD 1920x1080
# HP         15.6                     1366x768
# Lenovo     14.0                     1366x768
# HP         14.0            Full HD 1920x1080
# Acer       17.3  IPS Panel Full HD 1920x1080
# Dell       13.3  IPS Panel Full HD 1920x1080
# Asus       17.3            Full HD 1920x1080
# Lenovo     15.6                     1366x768
# Asus       11.6         Touchscreen 1366x768
# HP         14.0                     1366x768
#
#                                           Cpu   Ram                Memory  \
# Company
# HP                Intel Core i7 7700HQ 2.8GHz   8GB  128GB SSD +  1TB HDD
# HP                 Intel Core i5 6200U 2.3GHz   4GB             500GB HDD
# Lenovo   Intel Celeron Dual Core N3060 1.6GHz   2GB    32GB Flash Storage
# HP                 Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# Acer               Intel Core i3 7130U 2.7GHz   4GB               1TB HDD
# Dell               Intel Core i5 8250U 1.6GHz   4GB             256GB SSD
# Asus              Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# Lenovo               Intel Core i3 6006U 2GHz   4GB               1TB HDD
# Asus     Intel Celeron Dual Core N3350 1.1GHz   4GB    32GB Flash Storage
# HP                 Intel Core i5 7200U 2.5GHz   4GB             500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros
# Company
# HP         Nvidia GeForce GTX 1050  Windows 10  3.35kg      1191.00
# HP           Intel HD Graphics 520       No OS   2.1kg       476.99
# Lenovo       Intel HD Graphics 400  Windows 10  1.42kg       249.00
# HP           Intel HD Graphics 620  Windows 10  1.64kg      1010.51
# Acer          Nvidia GeForce MX130  Windows 10     3kg       655.00
# Dell                AMD Radeon 530  Windows 10   1.4kg       818.35
# Asus     Nvidia GeForce GTX1050 Ti  Windows 10     3kg      1504.00
# Lenovo          AMD Radeon R5 M430       No OS   1.9kg       368.00
# Asus         Intel HD Graphics 500  Windows 10   1.5kg       375.00
# HP           Intel HD Graphics 620  Windows 10  1.64kg       779.00

# %%
laptop_data['TypeName'].unique()
# Out:
# array(['Ultrabook', 'Notebook', 'Netbook', 'Gaming', '2 in 1 Convertible',
#        'Workstation'], dtype=object)

# %%
laptop_data.TypeName.value_counts()
# Out:
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: TypeName, dtype: int64

# %%
plt.figure(figsize=(12, 8))
laptop_data['TypeName'].value_counts().plot(kind='bar')

plt.title('Laptops by company', fontsize=15)

plt.xlabel('Company', fontsize=12)


plt.ylabel('Frequency', fontsize=12)
plt.show()

# %%
laptop_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1303 entries, Apple to Asus
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Product           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 132.3+ KB

# %%
plt.figure(figsize=(12, 8))
laptop_data[['Price_euros']].boxplot()

# %%
plt.figure(figsize=(12, 8))
sns.swarmplot(x='TypeName', y='Price_euros', data=laptop_data)

plt.title('Price distribution by type', fontsize=15)
plt.xlabel('Company', fontsize=12)
plt.ylabel('Price (in euros)', fontsize=12)
plt.show()
